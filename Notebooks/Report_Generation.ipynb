# %% [markdown]
# # Report Generation Example
#
# The following generates document from model of Concussion Detection System.

# %%
import jinja2
import capellambse


from IPython.core.display import HTML

resources = {
    "CR_Ventilator_Sim": "CR_Ventilator_Sim/CR_Ventilator_Sim",
}
path_to_model = "../CR_Ventilator.aird"
model = capellambse.MelodyModel(path_to_model, resources=resources, jupyter_untrusted=False)

env = jinja2.Environment()
# Out:
# /tmp/ipykernel_24898/2502675179.py:11: DeprecationWarning: The 'jupyter_untrusted' argument is no longer needed and will be removed soon. Please remove it from your calls.
#   model = capellambse.MelodyModel(path_to_model, resources=resources, jupyter_untrusted=False)
# Duplicate UUID '_LB2MSY7lEeqNepwDMv-GAw' within fragment CR_Ventilator.aird
# Duplicate UUID '_LB2MS47lEeqNepwDMv-GAw' within fragment CR_Ventilator.aird
# Duplicate UUID '_LB2MTY7lEeqNepwDMv-GAw' within fragment CR_Ventilator.aird
# Duplicate UUID '_LB2MT47lEeqNepwDMv-GAw' within fragment CR_Ventilator.aird
# Duplicate UUID '_LB2MUY7lEeqNepwDMv-GAw' within fragment CR_Ventilator.aird
# Duplicate UUID '_LB2MU47lEeqNepwDMv-GAw' within fragment CR_Ventilator.aird
# Cannot load PVMT extension: ValueError: Provided model does not have a PropertyValuePkg
# Property values are not available in this model

# %% [markdown]
# Below defines a set of routines that use Jinga templates to generate report.

# %%
def Generate_Operational_Process_Report(op):
    templ = """
    <h1 style= "padding-left: 0"style= "padding-left: 0">Operational Process {{ op.name }} - <span style="font-size: 10px" > UUID: {{ op.uuid }} </span> </h2>
    <p>{{ op.description }}</p>
    {% if op.applied_property_values %}
    <p  >The table below identifies property values of {{ op.name }}.</p>
        <table  style="border: 2px solid black; width:100% " >
            <tr>
                <th style="text-align:left ;border: 1px solid black" >Property Name </th>
                <th style="text-align:left ; border: 1px solid black">Property Value</th>
            </tr>
           {% for pv in node.applied_property_values %}
            <tr>
                <td style="text-align:left ; border: 1px solid black">{{ pv.name }}</td>
                <td style="text-align:left ; border: 1px solid black">{{ pv.value }}</td>
            </tr>
          {% endfor %}
           </table>
         <p style="text-align: center;"><strong>Property Values of {{ op.name }}</strong></p>
    {% else %}
        <p style="text-align: left;">No property values were identified.</p>
    {% endif %}   
    {% if op.property_value_groups %}
    <p  >The table below identifies property values groups of {{ op.name }}.</p>
        <table  style="border: 2px solid black; width:100% " >
            <tr>
                <th style="text-align:left ;border: 1px solid black" >Property Group Name </th>
                <th style="text-align:left ; border: 1px solid black">Property Summary</th>
            </tr>
            {% set pvgs = node %}

               {% for pvgs in pvgs.applied_property_value_groups %}
                <tr>
                    <td style="text-align:left ; border: 1px solid black">{{ pvgs.name }}</td>
                    <td style="text-align:left ; border: 1px solid black">{{ pvgs.summary }}</td>
                </tr>
                <tr>
                    <td style="text-align:right ; border: 1px solid black"> Properties of {{ pvgs.name  }}</td>
                    <td style="text-align:left ; border: 1px solid black"> 
                            <table  style="border: 1px solid black; width:100% " >
                                <tr>
                                    <th style="text-align:left ;border: 1px solid black">Property Name  </th>
                                    <th style="text-align:left ; border: 1px solid black"> Property Value </th>
                                </tr>
                            {% for pvs in pvgs.property_values %}
                            <tr>
                                <td style="text-align:left ; border: 1px solid black">{{ pvs.name }} </td>
                                <td style="text-align:left ; border: 1px solid black">{{ pvs.value }}</td>
                            </tr>
                           {% endfor %}
                           </table>

                  </td>
                </tr>
               {% endfor %}

           </table>
         <p style="text-align: center;"><strong>Property Values Groups {{ op.name }}</strong></p>
    {% else %}
        <p style="text-align: left;">No property values groups were identified.</p>
    {% endif %}
    """
    return templ

def Generate_Physical_Actor_Report( model ):
    templ = """
    <h1 style= "padding-left: 0" >Actor descritions</h1>
    {% for actor in model.pa.all_components.by_is_actor(True) %}
        <h2>{{ actor.name }} - <span style="font-size: 10px" > UUID: {{ actor.uuid }} </span> </h2>
        <p>{{ actor.description }}</p>
        {% if actor.applied_property_values %}
            <p  >The table below identifies property values of {{ node.name }}.</p>
                <table  style="border: 2px solid black; width:100% " >
                    <tr>
                        <th style="text-align:left ;border: 1px solid black" >Property Name </th>
                        <th style="text-align:left ; border: 1px solid black">Property Value</th>
                    </tr>
                   {% for pv in node.applied_property_values %}
                    <tr>
                        <td style="text-align:left ; border: 1px solid black">{{ pv.name }}</td>
                        <td style="text-align:left ; border: 1px solid black">{{ pv.value }}</td>
                    </tr>
                  {% endfor %}
                   </table>
                 <p style="text-align: center;"><strong>Property Values of {{ actor.name }}</strong></p>
            {% else %}
                <p style="text-align: left;">No property values were identified for{{ actor.name }}</p>
            {% endif %}   
            {% if actor.property_value_groups %}
            <p  >The table below identifies property values groups of {{ actor.name }}.</p>
                <table  style="border: 2px solid black; width:100% " >
                    <tr>
                        <th style="text-align:left ;border: 1px solid black" >Property Group Name </th>
                        <th style="text-align:left ; border: 1px solid black">Property Summary</th>
                    </tr>
                    {% set pvgs = node %}
                       {% for pvgs in pvgs.applied_property_value_groups %}
                        <tr>
                            <td style="text-align:left ; border: 1px solid black">{{ pvgs.name }}</td>
                            <td style="text-align:left ; border: 1px solid black">{{ pvgs.summary }}</td>
                        </tr>
                        <tr>
                            <td style="text-align:right ; border: 1px solid black"> Properties of {{ pvgs.name  }}</td>
                            <td style="text-align:left ; border: 1px solid black"> 
                                    <table  style="border: 1px solid black; width:100% " >
                                        <tr>
                                            <th style="text-align:left ;border: 1px solid black">Property Name  </th>
                                            <th style="text-align:left ; border: 1px solid black"> Property Value </th>
                                        </tr>
                                    {% for pvs in pvgs.property_values %}
                                    <tr>
                                        <td style="text-align:left ; border: 1px solid black">{{ pvs.name }} </td>
                                        <td style="text-align:left ; border: 1px solid black">{{ pvs.value }}</td>
                                    </tr>
                                   {% endfor %}
                                   </table>
                          </td>
                        </tr>
                       {% endfor %}
                   </table>
                 <p style="text-align: center;"><strong>Property Values Groups of {{ actor.name }}</strong></p>
            {% else %}
                <p style="text-align: left;">No property values groups were identified for of {{actor.name }}</p>
            {% endif %}
        <h3> {{ actor.name }} Ports </h3>
        {% for port in actor.physical_ports %}
            <p>{{ port.name }} - <span style="font-size: 10px" > UUID: {{ port.uuid }} </span>  </p>
            <p>{{ port.description }} </p>
            {% if port.property_values %}
            <p  >The table below identifies property values of {{ port.name }}.</p>
                <table  style="border: 2px solid black; width:100% " >
                    <tr>
                        <th style="text-align:left; border: 1px solid black" >Port </th>
                        <th style="text-align:left ;border: 1px solid black" >Property Name </th>
                        <th style="text-align:left ; border: 1px solid black">Property Value</th>
                    </tr>
                   {% for pv in port.property_values %}
                    <tr>
                        <td style="text-align:left ; border: 1px solid black" >
                            <p>{{ port.uuid }}</p>
                            <p>{{ port.name }}</p>
                        </td>
                        <td style="text-align:left ; border: 1px solid black">{{ pv.name }}</td>
                        <td style="text-align:left ; border: 1px solid black">{{ pv.value }}</td>
                    </tr>
                  {% endfor %}
                   </table>
                <p style="text-align: center;"><strong>Property Values of {{ port.name }}</strong></p>
            {% else %}
                <p style="text-align: left;">No property values were identified for {{ port.name }}</p>
            {% endif %}
            {% if port.links %}
             <p  >The table below identifies Physical Links of {{ port.name }}.</p>
             <table  style="border: 2px solid black; width:100% " >
                <tr>
                    <th style="text-align:left ;border: 1px solid black" >Link Name </th>
                    <th style="text-align:left ; border: 1px solid black">Link uuid</th>
                </tr>
                {% for l in port.links %}
                    <tr>
                        <td style="text-align:left ; border: 1px solid black">{{ l.name }}</td>
                        <td style="text-align:left ; border: 1px solid black">{{ l.uuid }}</td>
                    </tr>
                {% endfor %}
                </table>
                    <p style="text-align: center;"><strong> Physical Port Links = {{ port.name }}</strong></p>
            {% else %}
                <p style="text-align: left;">No allocated component ports found for Physical Lins {{ port.name }}</p>
            {% endif %}
             {% if port.PortAllocation %}
             <p  >The table below identifies Physical Links of {{ port.name }}.</p>
             <table  style="border: 2px solid black; width:100% " >
                <tr>
                    <th style="text-align:left ;border: 1px solid black" >Link Name </th>
                    <th style="text-align:left ; border: 1px solid black">Link uuid</th>
                </tr>
                {% for l in port.PortAllocatio %}
                    <tr>
                        <td style="text-align:left ; border: 1px solid black">{{ l.name }}</td>
                        <td style="text-align:left ; border: 1px solid black">{{ l.uuid }}</td>
                    </tr>
                {% endfor %}
                </table>
                    <p style="text-align: center;"><strong> Physical Links of {{ port.name }}</strong></p>
            {% else %}
                <p style="text-align: left;">No allocated component ports links found for {{ port.name }}</p>
            {% endif %}
        {% endfor %}
    {% endfor %}
    """
    return templ
def Generate_Logical_Actor_Report( model ):
    templ = """
    <h1 style= "padding-left: 0" >Actor descritions</h1>
    {% for actor in model.la.all_components.by_is_actor(True) %}
        <h2>{{ actor.name }} - <span style="font-size: 10px" > UUID: {{ actor.uuid }} </span> </h2>
        <p>{{ actor.description }}</p>
        {% if actor.applied_property_values %}
            <p  >The table below identifies property values of {{ node.name }}.</p>
                <table  style="border: 2px solid black; width:100% " >
                    <tr>
                        <th style="text-align:left ;border: 1px solid black" >Property Name </th>
                        <th style="text-align:left ; border: 1px solid black">Property Value</th>
                    </tr>
                   {% for pv in node.applied_property_values %}
                    <tr>
                        <td style="text-align:left ; border: 1px solid black">{{ pv.name }}</td>
                        <td style="text-align:left ; border: 1px solid black">{{ pv.value }}</td>
                    </tr>
                  {% endfor %}
                   </table>
                 <p style="text-align: center;"><strong>Property Values of {{ actor.name }}</strong></p>
            {% else %}
                <p style="text-align: left;">No property values were identified for{{ actor.name }}</p>
            {% endif %}   
            {% if actor.property_value_groups %}
            <p  >The table below identifies property values groups of {{ actor.name }}.</p>
                <table  style="border: 2px solid black; width:100% " >
                    <tr>
                        <th style="text-align:left ;border: 1px solid black" >Property Group Name </th>
                        <th style="text-align:left ; border: 1px solid black">Property Summary</th>
                    </tr>
                    {% set pvgs = node %}
                       {% for pvgs in pvgs.applied_property_value_groups %}
                        <tr>
                            <td style="text-align:left ; border: 1px solid black">{{ pvgs.name }}</td>
                            <td style="text-align:left ; border: 1px solid black">{{ pvgs.summary }}</td>
                        </tr>
                        <tr>
                            <td style="text-align:right ; border: 1px solid black"> Properties of {{ pvgs.name  }}</td>
                            <td style="text-align:left ; border: 1px solid black"> 
                                    <table  style="border: 1px solid black; width:100% " >
                                        <tr>
                                            <th style="text-align:left ;border: 1px solid black">Property Name  </th>
                                            <th style="text-align:left ; border: 1px solid black"> Property Value </th>
                                        </tr>
                                    {% for pvs in pvgs.property_values %}
                                    <tr>
                                        <td style="text-align:left ; border: 1px solid black">{{ pvs.name }} </td>
                                        <td style="text-align:left ; border: 1px solid black">{{ pvs.value }}</td>
                                    </tr>
                                   {% endfor %}
                                   </table>
                          </td>
                        </tr>
                       {% endfor %}
                   </table>
                 <p style="text-align: center;"><strong>Property Values Groups of {{ actor.name }}</strong></p>
            {% else %}
                <p style="text-align: left;">No property values groups were identified for of {{actor.name }}</p>
            {% endif %}
        <h3> {{ actor.name }} Ports </h3>
        {% for port in actor.logical_ports %}
            <p>{{ port.name }} - <span style="font-size: 10px" > UUID: {{ port.uuid }} </span>  </p>
            <p>{{ port.description }} </p>
            {% if port.property_values %}
            <p  >The table below identifies property values of {{ port.name }}.</p>
                <table  style="border: 2px solid black; width:100% " >
                    <tr>
                        <th style="text-align:left; border: 1px solid black" >Port </th>
                        <th style="text-align:left ;border: 1px solid black" >Property Name </th>
                        <th style="text-align:left ; border: 1px solid black">Property Value</th>
                    </tr>
                   {% for pv in port.property_values %}
                    <tr>
                        <td style="text-align:left ; border: 1px solid black" >
                            <p>{{ port.uuid }}</p>
                            <p>{{ port.name }}</p>
                        </td>
                        <td style="text-align:left ; border: 1px solid black">{{ pv.name }}</td>
                        <td style="text-align:left ; border: 1px solid black">{{ pv.value }}</td>
                    </tr>
                  {% endfor %}
                   </table>
                <p style="text-align: center;"><strong>Property Values of {{ port.name }}</strong></p>
            {% else %}
                <p style="text-align: left;">No property values were identified for {{ port.name }}</p>
            {% endif %}
            {% if port.links %}
             <p  >The table below identifies Physical Links of {{ port.name }}.</p>
             <table  style="border: 2px solid black; width:100% " >
                <tr>
                    <th style="text-align:left ;border: 1px solid black" >Link Name </th>
                    <th style="text-align:left ; border: 1px solid black">Link uuid</th>
                </tr>
                {% for l in port.links %}
                    <tr>
                        <td style="text-align:left ; border: 1px solid black">{{ l.name }}</td>
                        <td style="text-align:left ; border: 1px solid black">{{ l.uuid }}</td>
                    </tr>
                {% endfor %}
                </table>
                    <p style="text-align: center;"><strong> Physical Port Links = {{ port.name }}</strong></p>
            {% else %}
                <p style="text-align: left;">No allocated component ports found for Physical Lins {{ port.name }}</p>
            {% endif %}
             {% if port.PortAllocation %}
             <p  >The table below identifies Physical Links of {{ port.name }}.</p>
             <table  style="border: 2px solid black; width:100% " >
                <tr>
                    <th style="text-align:left ;border: 1px solid black" >Link Name </th>
                    <th style="text-align:left ; border: 1px solid black">Link uuid</th>
                </tr>
                {% for l in port.PortAllocatio %}
                    <tr>
                        <td style="text-align:left ; border: 1px solid black">{{ l.name }}</td>
                        <td style="text-align:left ; border: 1px solid black">{{ l.uuid }}</td>
                    </tr>
                {% endfor %}
                </table>
                    <p style="text-align: center;"><strong> Physical Links of {{ port.name }}</strong></p>
            {% else %}
                <p style="text-align: left;">No allocated component ports links found for {{ port.name }}</p>
            {% endif %}
        {% endfor %}
    {% endfor %}
    """
    return templ

def Generate_Physical_Node_Components_Report( model ):
    templ = """

    <h1 style= "padding-left: 0" >Node descriptions</h1>
    {% for node in model.pa.all_components %}
        <h2>{{ node.name }} - <span style="font-size: 10px" > UUID: {{ node.uuid }} </span> </h2>
        <p>{{ node.description }}</p>
         {% if node.applied_property_values %}
            <p  >The table below identifies property values of {{ node.name }}.</p>
                <table  style="border: 2px solid black; width:100% " >
                    <tr>
                        <th style="text-align:left ;border: 1px solid black" >Property Name </th>
                        <th style="text-align:left ; border: 1px solid black">Property Value</th>
                    </tr>
                   {% for pv in node.applied_property_values %}
                    <tr>
                        <td style="text-align:left ; border: 1px solid black">{{ pv.name }}</td>
                        <td style="text-align:left ; border: 1px solid black">{{ pv.value }}</td>
                    </tr>
                  {% endfor %}
                   </table>
                 <p style="text-align: center;"><strong>Property Values of {{ node.name }}</strong></p>
            {% else %}
                <p style="text-align: left;">No property values were identified.</p>
            {% endif %}   
            {% if node.property_value_groups %}
            <p  >The table below identifies property values groups of {{ node.name }}.</p>
                <table  style="border: 2px solid black; width:100% " >
                    <tr>
                        <th style="text-align:left ;border: 1px solid black" >Property Group Name </th>
                        <th style="text-align:left ; border: 1px solid black">Property Summary</th>
                    </tr>
                    {% set pvgs = node %}

                       {% for pvgs in pvgs.applied_property_value_groups %}
                        <tr>
                            <td style="text-align:left ; border: 1px solid black">{{ pvgs.name }}</td>
                            <td style="text-align:left ; border: 1px solid black">{{ pvgs.summary }}</td>
                        </tr>
                        <tr>
                            <td style="text-align:right ; border: 1px solid black"> Properties of {{ pvgs.name  }}</td>
                            <td style="text-align:left ; border: 1px solid black"> 
                                    <table  style="border: 1px solid black; width:100% " >
                                        <tr>
                                            <th style="text-align:left ;border: 1px solid black">Property Name  </th>
                                            <th style="text-align:left ; border: 1px solid black"> Property Value </th>
                                        </tr>
                                    {% for pvs in pvgs.property_values %}
                                    <tr>
                                        <td style="text-align:left ; border: 1px solid black">{{ pvs.name }} </td>
                                        <td style="text-align:left ; border: 1px solid black">{{ pvs.value }}</td>
                                    </tr>
                                   {% endfor %}
                                   </table>

                          </td>
                        </tr>
                       {% endfor %}

                   </table>
                 <p style="text-align: center;"><strong>Property Values Groups {{ node.name }}</strong></p>
            {% else %}
                <p style="text-align: left;">No property values groups were identified.</p>
            {% endif %}
        <h3> {{ node.name }} Ports </h3>
        {% for port in node.physical_ports %}
            <p>{{ port.name }} - <span style="font-size: 10px" > UUID: {{ port.uuid }} </span>  </p>
            <p>{{ port.description }} </p>
            {% if port.property_values %}
            <p  >The table below identifies property values of {{ port.name }}.</p>
                <table  style="border: 2px solid black; width:100% " >
                    <tr>
                        <th style="text-align:left; border: 1px solid black" >Port </th>
                        <th style="text-align:left ;border: 1px solid black" >Property Name </th>
                        <th style="text-align:left ; border: 1px solid black">Property Value</th>
                    </tr>
                   {% for pv in port.property_values %}
                    <tr>
                        <td style="text-align:left ; border: 1px solid black" >
                            <p>{{ port.uuid }}</p>
                            <p>{{ port.name }}</p>
                        </td>
                        <td style="text-align:left ; border: 1px solid black">{{ pv.name }}</td>
                        <td style="text-align:left ; border: 1px solid black">{{ pv.value }}</td>
                    </tr>
                  {% endfor %}
                   </table>
                <p style="text-align: center;"><strong>Property Values of {{ port.name }}</strong></p>
            {% else %}
                <p style="text-align: left;">No property values were identified.</p>
            {% endif %}
            {% if port.links %}
             <p  >The table below identifies Physical Links of {{ port.name }}.</p>
             <table  style="border: 2px solid black; width:100% " >
                <tr>
                    <th style="text-align:left ;border: 1px solid black" >Link Name </th>
                    <th style="text-align:left ; border: 1px solid black">Link uuid</th>
                </tr>

                {% for l in port.links %}
                    <tr>
                        <td style="text-align:left ; border: 1px solid black">{{ l.name }}</td>
                        <td style="text-align:left ; border: 1px solid black">{{ l.uuid }}</td>
                    </tr>
                {% endfor %}
                </table>
                    <p style="text-align: center;"><strong> Physical Links = {{ port.name }}</strong></p>
            {% else %}
                <p style="text-align: left;">No allocated component ports found.</p>
            {% endif %}
             {% if port.PortAllocation %}
             <p  >The table below identifies Physical Links of {{ port.name }}.</p>
             <table  style="border: 2px solid black; width:100% " >
                <tr>
                    <th style="text-align:left ;border: 1px solid black" >Link Name </th>
                    <th style="text-align:left ; border: 1px solid black">Link uuid</th>
                </tr>

                {% for l in port.PortAllocatio %}
                    <tr>
                        <td style="text-align:left ; border: 1px solid black">{{ l.name }}</td>
                        <td style="text-align:left ; border: 1px solid black">{{ l.uuid }}</td>
                    </tr>
                {% endfor %}
                </table>
                    <p style="text-align: center;"><strong> Physical Links = {{ port.name }}</strong></p>
            {% else %}
                <p style="text-align: left;">No allocated component ports found.</p>
            {% endif %}
        {% endfor %}
    {% endfor %}
    """
    return templ

def Generate_Physical_Node_Component_Report( node ):
    templ = """
    <h1>{{ node.name }} - <span style="font-size: 10px" > UUID: {{ node.uuid }} </span> </h2>
    <p>{{ node.description }}</p>
     {% if node.applied_property_values %}
        <p  >The table below identifies property values of {{ node.name }}.</p>
            <table  style="border: 2px solid black; width:100% " >
                <tr>
                    <th style="text-align:left ;border: 1px solid black" >Property Name </th>
                    <th style="text-align:left ; border: 1px solid black">Property Value</th>
                </tr>
               {% for pv in node.applied_property_values %}
                <tr>
                    <td style="text-align:left ; border: 1px solid black">{{ pv.name }}</td>
                    <td style="text-align:left ; border: 1px solid black">{{ pv.value }}</td>
                </tr>
              {% endfor %}
               </table>
             <p style="text-align: center;"><strong>Property Values of {{ node.name }}</strong></p>
        {% else %}
            <p style="text-align: left;">No property values were identified.</p>
        {% endif %}   
        {% if node.property_value_groups %}
        <p  >The table below identifies property values groups of {{ node.name }}.</p>
            <table  style="border: 2px solid black; width:100% " >
                <tr>
                    <th style="text-align:left ;border: 1px solid black" >Property Group Name </th>
                    <th style="text-align:left ; border: 1px solid black">Property Summary</th>
                </tr>
                {% set pvgs = node %}

                   {% for pvgs in pvgs.applied_property_value_groups %}
                    <tr>
                        <td style="text-align:left ; border: 1px solid black">{{ pvgs.name }}</td>
                        <td style="text-align:left ; border: 1px solid black">{{ pvgs.summary }}</td>
                    </tr>
                    <tr>
                        <td style="text-align:right ; border: 1px solid black"> Properties of {{ pvgs.name  }}</td>
                        <td style="text-align:left ; border: 1px solid black"> 
                                <table  style="border: 1px solid black; width:100% " >
                                    <tr>
                                        <th style="text-align:left ;border: 1px solid black">Property Name  </th>
                                        <th style="text-align:left ; border: 1px solid black"> Property Value </th>
                                    </tr>
                                {% for pvs in pvgs.property_values %}
                                <tr>
                                    <td style="text-align:left ; border: 1px solid black">{{ pvs.name }} </td>
                                    <td style="text-align:left ; border: 1px solid black">{{ pvs.value }}</td>
                                </tr>
                               {% endfor %}
                               </table>

                      </td>
                    </tr>
                   {% endfor %}

               </table>
             <p style="text-align: center;"><strong>Property Values Groups {{ node.name }}</strong></p>
        {% else %}
            <p style="text-align: left;">No property values groups were identified.</p>
        {% endif %}
    <h3> {{ node.name }} Ports </h3>
    {% for port in node.physical_ports %}
        <p>{{ port.name }} - <span style="font-size: 10px" > UUID: {{ port.uuid }} </span>  </p>
        <p>{{ port.description }} </p>
        {% if port.property_values %}
        <p  >The table below identifies property values of {{ port.name }}.</p>
            <table  style="border: 2px solid black; width:100% " >
                <tr>
                    <th style="text-align:left; border: 1px solid black" >Port </th>
                    <th style="text-align:left ;border: 1px solid black" >Property Name </th>
                    <th style="text-align:left ; border: 1px solid black">Property Value</th>
                </tr>
               {% for pv in port.property_values %}
                <tr>
                    <td style="text-align:left ; border: 1px solid black" >
                        <p>{{ port.uuid }}</p>
                        <p>{{ port.name }}</p>
                    </td>
                    <td style="text-align:left ; border: 1px solid black">{{ pv.name }}</td>
                    <td style="text-align:left ; border: 1px solid black">{{ pv.value }}</td>
                </tr>
              {% endfor %}
               </table>
            <p style="text-align: center;"><strong>Property Values of {{ port.name }}</strong></p>
        {% else %}
            <p style="text-align: left;">No property values were identified.</p>
        {% endif %}
        {% if port.links %}
         <p  >The table below identifies Physical Links of {{ port.name }}.</p>
         <table  style="border: 2px solid black; width:100% " >
            <tr>
                <th style="text-align:left ;border: 1px solid black" >Link Name </th>
                <th style="text-align:left ; border: 1px solid black">Link uuid</th>
            </tr>

            {% for l in port.links %}
                <tr>
                    <td style="text-align:left ; border: 1px solid black">{{ l.name }}</td>
                    <td style="text-align:left ; border: 1px solid black">{{ l.uuid }}</td>
                </tr>
            {% endfor %}
            </table>
                <p style="text-align: center;"><strong> Physical Links = {{ port.name }}</strong></p>
        {% else %}
            <p style="text-align: left;">No allocated component ports found.</p>
        {% endif %}
         {% if port.PortAllocation %}
         <p  >The table below identifies Physical Links of {{ port.name }}.</p>
         <table  style="border: 2px solid black; width:100% " >
            <tr>
                <th style="text-align:left ;border: 1px solid black" >Link Name </th>
                <th style="text-align:left ; border: 1px solid black">Link uuid</th>
            </tr>

            {% for l in port.PortAllocatio %}
                <tr>
                    <td style="text-align:left ; border: 1px solid black">{{ l.name }}</td>
                    <td style="text-align:left ; border: 1px solid black">{{ l.uuid }}</td>
                </tr>
            {% endfor %}
            </table>
                <p style="text-align: center;"><strong> Physical Links = {{ port.name }}</strong></p>
        {% else %}
            <p style="text-align: left;">No allocated component ports found.</p>
        {% endif %}
    {% endfor %}
 
    """
    return templ

def Generate_Physical_Interface_Report( model ):
    templ = """

    <h1 style= "padding-left: 0" >Interfaces </h1>
    {% for node in model.pa.all_interfaces %}
        <h2>{{ node.name }} - <span style="font-size: 10px" > UUID: {{ node.uuid }} </span> </h2>
        <p>{{ node.description }}</p>
        <h3> {{ node.name }} Ports </h3>
        {% for port in node.physical_ports %}
            <p>{{ port.name }} - <span style="font-size: 10px" > UUID: {{ port.uuid }} </span>  </p>
            <p>{{ port.description }} </p>
            {% if port.property_values %}
            <p  >The table below identifies property values of {{ port.name }}.</p>
                <table  style="border: 2px solid black; width:100% " >
                    <tr>
                        <th style="text-align:left; border: 1px solid black" > Port </th>
                        <th style="text-align:left ;border: 1px solid black" >Property Name </th>
                        <th style="text-align:left ; border: 1px solid black">Property Value</th>
                    </tr>
                {% for pv in port.property_values %}

                    <tr>
                        <td style="text-align:left ; border: 1px solid black" >
                            <p>{{ port.uuid }}</p>
                            <p>{{ port.name }}</p>
                        </td>
                        <td style="text-align:left ; border: 1px solid black">{{ pv.name }}</td>
                        <td style="text-align:left ; border: 1px solid black">{{ pv.value }}</td>
                    </tr>
                {% endfor %}
                </table>
                    <p style="text-align: center;"><strong>Property Values of {{ port.name }}</strong></p>
            {% else %}
                <p style="text-align: left;">No property values were identified.</p>
            {% endif %}
        {% endfor %}
    {% endfor %}
    """
    return templ

# %% [markdown]
# # Physical Actors
#
# The following generates document of the Physical Actors from configured model of Concussion Detection System.

# %%
HTML(env.from_string(Generate_Physical_Actor_Report(model)).render(model=model))
# Out:
#     <h1 style= "padding-left: 0" >Actor descritions</h1>
#
#         <h2>Therapist - <span style="font-size: 10px" > UUID: e78660aa-d88d-4a4c-b806-ee81285ea619 </span> </h2>
#         <p></p>
#
#                 <p style="text-align: left;">No property values were identified forTherapist</p>
#
#
#                 <p style="text-align: left;">No property values groups were identified for of Therapist</p>
#
#         <h3> Therapist Ports </h3>
#
#             <p>PP 1 - <span style="font-size: 10px" > UUID: ac80f46a-6998-4d09-821e-24aa87d5586b </span>  </p>
#             <p> </p>
#
#                 <p style="text-align: left;">No property values were identified for PP 1</p>
#
#
#              <p  >The table below identifies Physical Links of PP 1.</p>
#              <table  style="border: 2px solid black; width:100% " >
#                 <tr>
#                     <th style="text-align:left ;border: 1px solid black" >Link Name </th>
#                     <th style="text-align:left ; border: 1px solid black">Link uuid</th>
#                 </tr>
#
#                     <tr>
#                         <td style="text-align:left ; border: 1px solid black">UI</td>
#                         <td style="text-align:left ; border: 1px solid black">0603be91-55da-4ee7-8778-c118701d000f</td>
#                     </tr>
#
#                 </table>
#                     <p style="text-align: center;"><strong> Physical Port Links = PP 1</strong></p>
#
#
#                 <p style="text-align: left;">No allocated component ports links found for PP 1</p>
#
#
#
#         <h2>Clinciaon in Room - <span style="font-size: 10px" > UUID: 55314e6e-e98a-429f-8472-7a8435dc2be3 </span> </h2>
#         <p></p>
#
#                 <p style="text-align: left;">No property values were identified forClinciaon in Room</p>
#
#
#                 <p style="text-align: left;">No property values groups were identified for of Clinciaon in Room</p>
#
#         <h3> Clinciaon in Room Ports </h3>
#
#             <p>PP 1 - <span style="font-size: 10px" > UUID: b1a9606d-6fd4-4564-949b-37262b2510a9 </span>  </p>
#             <p> </p>
#
#                 <p style="text-align: left;">No property values were identified for PP 1</p>
#
#
#              <p  >The table below identifies Physical Links of PP 1.</p>
#              <table  style="border: 2px solid black; width:100% " >
#                 <tr>
#                     <th style="text-align:left ;border: 1px solid black" >Link Name </th>
#                     <th style="text-align:left ; border: 1px solid black">Link uuid</th>
#                 </tr>
#
#                     <tr>
#                         <td style="text-align:left ; border: 1px solid black">PL 2</td>
#                         <td style="text-align:left ; border: 1px solid black">61bca5b7-bb4f-4a1a-9b03-80a30d896566</td>
#                     </tr>
#
#                 </table>
#                     <p style="text-align: center;"><strong> Physical Port Links = PP 1</strong></p>
#
#
#                 <p style="text-align: left;">No allocated component ports links found for PP 1</p>
#
#
#
#         <h2>Patient - <span style="font-size: 10px" > UUID: 01e96448-a457-493b-91b6-5e31ac282cf3 </span> </h2>
#         <p></p>
#
#                 <p style="text-align: left;">No property values were identified forPatient</p>
#
#
#                 <p style="text-align: left;">No property values groups were identified for of Patient</p>
#
#         <h3> Patient Ports </h3>
#
#             <p>PP 1 - <span style="font-size: 10px" > UUID: 6caf1934-9fde-452e-a4c2-fc8a163d7185 </span>  </p>
#             <p> </p>
#
#                 <p style="text-align: left;">No property values were identified for PP 1</p>
#
#
#              <p  >The table below identifies Physical Links of PP 1.</p>
#              <table  style="border: 2px solid black; width:100% " >
#                 <tr>
#                     <th style="text-align:left ;border: 1px solid black" >Link Name </th>
#                     <th style="text-align:left ; border: 1px solid black">Link uuid</th>
#                 </tr>
#
#                     <tr>
#                         <td style="text-align:left ; border: 1px solid black">Circ-P</td>
#                         <td style="text-align:left ; border: 1px solid black">1ee20231-6b78-4e71-ad6d-2abc3f79aedc</td>
#                     </tr>
#
#                 </table>
#                     <p style="text-align: center;"><strong> Physical Port Links = PP 1</strong></p>
#
#
#                 <p style="text-align: left;">No allocated component ports links found for PP 1</p>
#
#
#
#         <h2>Patient Support Care Givers - <span style="font-size: 10px" > UUID: d2192a11-5a50-4310-892e-56868f123755 </span> </h2>
#         <p></p>
#
#                 <p style="text-align: left;">No property values were identified forPatient Support Care Givers</p>
#
#
#                 <p style="text-align: left;">No property values groups were identified for of Patient Support Care Givers</p>
#
#         <h3> Patient Support Care Givers Ports </h3>
#
#
#         <h2>Hospital System - <span style="font-size: 10px" > UUID: 3143ec95-10e7-4b44-b2c2-29f46818fbd1 </span> </h2>
#         <p></p>
#
#                 <p style="text-align: left;">No property values were identified forHospital System</p>
#
#
#                 <p style="text-align: left;">No property values groups were identified for of Hospital System</p>
#
#         <h3> Hospital System Ports </h3>
#
#
#         <h2>Ventilator Manufacturer - <span style="font-size: 10px" > UUID: b01aef93-8da5-46a5-a42e-5bb387922fe7 </span> </h2>
#         <p></p>
#
#                 <p style="text-align: left;">No property values were identified forVentilator Manufacturer</p>
#
#
#                 <p style="text-align: left;">No property values groups were identified for of Ventilator Manufacturer</p>
#
#         <h3> Ventilator Manufacturer Ports </h3>
#
#
#         <h2>Ventilator Distributor - <span style="font-size: 10px" > UUID: 7f9dbef1-10e8-4627-83f7-e8eb1470265f </span> </h2>
#         <p></p>
#
#                 <p style="text-align: left;">No property values were identified forVentilator Distributor</p>
#
#
#                 <p style="text-align: left;">No property values groups were identified for of Ventilator Distributor</p>
#
#         <h3> Ventilator Distributor Ports </h3>
#
#
#         <h2>Environment - <span style="font-size: 10px" > UUID: ce114389-67c1-44c4-860c-da29bfc02237 </span> </h2>
#         <p></p>
#
#                 <p style="text-align: left;">No property values were identified forEnvironment</p>
#
#
#                 <p style="text-align: left;">No property values groups were identified for of Environment</p>
#
#         <h3> Environment Ports </h3>

# %% [markdown]
# # Physical Nodes
#
# The following generates report Nodes from model of Concussion Detection System.

# %%
HTML(env.from_string(Generate_Physical_Node_Components_Report(model)).render(model=model))
# Out:
#     <h1 style= "padding-left: 0" >Node descriptions</h1>
#
#         <h2>Physical System - <span style="font-size: 10px" > UUID: 8cb393d1-accd-41bc-941e-26ca6ea5a20e </span> </h2>
#         <p></p>
#
#                 <p style="text-align: left;">No property values were identified.</p>
#
#
#                 <p style="text-align: left;">No property values groups were identified.</p>
#
#         <h3> Physical System Ports </h3>
#
#
#         <h2>Ventilator - <span style="font-size: 10px" > UUID: df3ece25-a091-438e-8848-3680c8cdb4e6 </span> </h2>
#         <p><p>A <b>Ventilator</b> is a medical device used to support or substitute for spontaneous breathing. It is also known as a respirator, and is typically used in critical care and emergency situations to assist patients with breathing. Ventilators work by providing a positive pressure to the patient&#39;s lungs, which helps them to fill with air and expel carbon dioxide. The ventilator also monitors and adjusts the pressure and flow of the air, as well as the patient&#39;s oxygen levels. Ventilators can be used for a variety of medical conditions, including respiratory failure, respiratory distress syndrome, and post-operative care. They can also be used to provide support for critically ill patients and those in intensive care units. <i>References:</i></p>
#
# <ul>
# 	<li>Papalia, S., D&rsquo;Ausilio, A., &amp; Festa, R. (2020). Respiratory support in the intensive care unit. <i>International Journal of Environmental Research and Public Health, 17</i>(7), 2434.</li>
# </ul>
# </p>
#
#                 <p style="text-align: left;">No property values were identified.</p>
#
#
#                 <p style="text-align: left;">No property values groups were identified.</p>
#
#         <h3> Ventilator Ports </h3>
#
#             <p>PP 13 - <span style="font-size: 10px" > UUID: 79745f94-b28c-4326-bf71-09abd1056548 </span>  </p>
#             <p> </p>
#
#                 <p style="text-align: left;">No property values were identified.</p>
#
#
#              <p  >The table below identifies Physical Links of PP 13.</p>
#              <table  style="border: 2px solid black; width:100% " >
#                 <tr>
#                     <th style="text-align:left ;border: 1px solid black" >Link Name </th>
#                     <th style="text-align:left ; border: 1px solid black">Link uuid</th>
#                 </tr>
#
#
#                     <tr>
#                         <td style="text-align:left ; border: 1px solid black">USB</td>
#                         <td style="text-align:left ; border: 1px solid black">9af93b95-9a39-4429-9055-ba91b8231c90</td>
#                     </tr>
#
#                     <tr>
#                         <td style="text-align:left ; border: 1px solid black">USB Port</td>
#                         <td style="text-align:left ; border: 1px solid black">45ece7ee-a4ac-4a30-bc63-7845891dd093</td>
#                     </tr>
#
#                 </table>
#                     <p style="text-align: center;"><strong> Physical Links = PP 13</strong></p>
#
#
#                 <p style="text-align: left;">No allocated component ports found.</p>
#
#
#
#         <h2>CPU PCBA - <span style="font-size: 10px" > UUID: d83f84ca-c400-4465-9ae9-2a0dd622b87a </span> </h2>
#         <p><p><span style="text-align: left; color: rgb(36, 39, 41); text-transform: none; text-indent: 0px; letter-spacing: normal; font-family: Arial, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 13px; font-style: normal; font-weight: 400; word-spacing: 0px; float: none; display: inline !important; white-space: normal; orphans: 2; widows: 2; background-color: rgb(255, 255, 255); font-variant-ligatures: normal; font-variant-caps: normal; -webkit-text-stroke-width: 0px; text-decoration-style: initial; text-decoration-color: initial;">ST10F278</span></p>
# </p>
#
#                 <p style="text-align: left;">No property values were identified.</p>
#
#
#                 <p style="text-align: left;">No property values groups were identified.</p>
#
#         <h3> CPU PCBA Ports </h3>
#
#             <p>PP 1 - <span style="font-size: 10px" > UUID: 3a6d614d-0136-457e-bcec-119c32ebf464 </span>  </p>
#             <p> </p>
#
#                 <p style="text-align: left;">No property values were identified.</p>
#
#
#              <p  >The table below identifies Physical Links of PP 1.</p>
#              <table  style="border: 2px solid black; width:100% " >
#                 <tr>
#                     <th style="text-align:left ;border: 1px solid black" >Link Name </th>
#                     <th style="text-align:left ; border: 1px solid black">Link uuid</th>
#                 </tr>
#
#
#                     <tr>
#                         <td style="text-align:left ; border: 1px solid black">CPU-TB</td>
#                         <td style="text-align:left ; border: 1px solid black">421f4c3a-deaf-42b0-8ed8-80481faa6ab0</td>
#                     </tr>
#
#                 </table>
#                     <p style="text-align: center;"><strong> Physical Links = PP 1</strong></p>
#
#
#                 <p style="text-align: left;">No allocated component ports found.</p>
#
#
#             <p>PP 2 - <span style="font-size: 10px" > UUID: 4d4fea7f-1924-47bd-87cd-6764fa72a36f </span>  </p>
#             <p> </p>
#
#                 <p style="text-align: left;">No property values were identified.</p>
#
#
#              <p  >The table below identifies Physical Links of PP 2.</p>
#              <table  style="border: 2px solid black; width:100% " >
#                 <tr>
#                     <th style="text-align:left ;border: 1px solid black" >Link Name </th>
#                     <th style="text-align:left ; border: 1px solid black">Link uuid</th>
#                 </tr>
#
#
#                     <tr>
#                         <td style="text-align:left ; border: 1px solid black">Buzzer</td>
#                         <td style="text-align:left ; border: 1px solid black">1a107a58-ded7-4fc6-874b-6c7c2bbdd345</td>
#                     </tr>
#
#                 </table>
#                     <p style="text-align: center;"><strong> Physical Links = PP 2</strong></p>
#
#
#                 <p style="text-align: left;">No allocated component ports found.</p>
#
#
#             <p>PP 4 - <span style="font-size: 10px" > UUID: 207f9dec-6853-4518-a5dd-88f78360c339 </span>  </p>
#             <p> </p>
#
#                 <p style="text-align: left;">No property values were identified.</p>
#
#
#              <p  >The table below identifies Physical Links of PP 4.</p>
#              <table  style="border: 2px solid black; width:100% " >
#                 <tr>
#                     <th style="text-align:left ;border: 1px solid black" >Link Name </th>
#                     <th style="text-align:left ; border: 1px solid black">Link uuid</th>
#                 </tr>
#
#
#                     <tr>
#                         <td style="text-align:left ; border: 1px solid black">LCD</td>
#                         <td style="text-align:left ; border: 1px solid black">105d88b9-fe2b-4470-9226-6eec92af2860</td>
#                     </tr>
#
#                 </table>
#                     <p style="text-align: center;"><strong> Physical Links = PP 4</strong></p>
#
#
#                 <p style="text-align: left;">No allocated component ports found.</p>
#
#
#             <p>PP 5 - <span style="font-size: 10px" > UUID: 6df21c08-e807-45ef-ad73-16f0ee3717c2 </span>  </p>
#             <p> </p>
#
#                 <p style="text-align: left;">No property values
